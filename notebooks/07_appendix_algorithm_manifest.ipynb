# %% [markdown]
# # 07 Appendix Algorithm and Theory-to-Artifact Manifest
#
# Appendix experiment for Algorithm 1 and the Algorithm 1 consistency checks. It records which code artifact tests each theoretical result and verifies that Algorithm 1 returns only the three intended decision states.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
while PROJECT_ROOT.name != "privacy_robust_incrementality_measurement" and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
SRC = PROJECT_ROOT / "code" / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from config import ProjectPaths
paths = ProjectPaths.from_cwd(PROJECT_ROOT)
paths
# Out:
# ProjectPaths(project_root=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement'), code_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code'), data_dir=PosixPath('/home/apex/Documents/ranking_sys/data'), artifact_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code/artifacts'), figure_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code/artifacts/figures'), table_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code/artifacts/tables'), workspace_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code/artifacts/workspace'))

# %%
from data import load_all
from experiments import algorithm_validity_checks, main_frontier_results, theory_artifact_manifest
from tables import write_table

datasets = load_all(paths.data_dir)
frontier = main_frontier_results(datasets)
algorithm_check = algorithm_validity_checks(frontier)
manifest = theory_artifact_manifest()
write_table(algorithm_check, paths.table_dir / "algorithm_validity_check.csv")
write_table(manifest, paths.table_dir / "theory_to_artifact_manifest.csv")
display(algorithm_check)
manifest
# Out:
#            dataset  rows  valid_pop_states  valid_finite_states  \
# 0    Criteo Uplift     6              True                 True
# 1  Hillstrom Email     6              True                 True
#
#    pop_rule_consistent  finite_rule_consistent  suppressed_unresolved  \
# 0                 True                    True                   True
# 1                 True                    True                   True
#
#    finite_contains_population_band  n_certify  n_reject  n_unresolved
# 0                             True          0         0             6
# 1                             True          0         0             6
#             result                                            claim                                      experiment paper_location                     primary_artifact
# 0      Theorem 5.1        Sharp privacy-loss certification frontier            01_main_certification_frontier.ipynb           main            privacy_frontier_main.png
# ...
