# %% [markdown]
# # 02 Main Sample Complexity and Minimax Diagnostics
#
# Main-body experiment for Proposition 5.2 and Theorem 5.3. The plots compare the finite-sample certification radius with the minimax lower-bound scale under retention loss.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
while PROJECT_ROOT.name != "privacy_robust_incrementality_measurement" and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
SRC = PROJECT_ROOT / "code" / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from config import ProjectPaths
paths = ProjectPaths.from_cwd(PROJECT_ROOT)
paths
# Out:
# ProjectPaths(project_root=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement'), code_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code'), data_dir=PosixPath('/home/apex/Documents/ranking_sys/data'), artifact_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code/artifacts'), figure_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code/artifacts/figures'), table_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code/artifacts/tables'), workspace_dir=PosixPath('/home/apex/Documents/ranking_sys/notebooks/writing/privacy_robust_incrementality_measurement/code/artifacts/workspace'))

# %%
from experiments import sample_complexity_grid, required_sample_table
from figures import plot_sample_complexity
from tables import write_table

grid = sample_complexity_grid()
required = required_sample_table()
write_table(grid, paths.table_dir / "sample_complexity_grid.csv")
write_table(required, paths.table_dir / "sample_complexity_required_n.csv")
required
# Out:
#     epsilon  q_min  required_n_no_noise  required_n_sigma_3
# 0     0.020   0.90               186669              186669
# 1     0.020   0.70               308575              308575
# 2     0.020   0.50               604807              604807
# 3     0.020   0.30              1680018             1680018
# 4     0.020   0.15              6720072             6720072
# 5     0.010   0.90               746675              746675
# 6     0.010   0.70              1234299             1234299
# 7     0.010   0.50              2419226             2419226
# 8     0.010   0.30              6720072             6720072
# 9     0.010   0.15             26880287            26880287
# 10    0.005   0.90              2986699             2986699
# 11    0.005   0.70              4937196             4937196
# 12    0.005   0.50              9676903             9676903
# 13    0.005   0.30             26880287            26880287
# 14    0.005   0.15            107521145           107521145

# %%
plot_sample_complexity(grid, paths.figure_dir / "sample_complexity_main.png")
